# %% [markdown]
# # Clustering Analysis Spotify's Top 100 Songs of 2017

# %% [markdown]
# ## Objective
#
# This is an investigation of a dataset comprising [Spotify's top 100 songs of 2017](https://www.kaggle.com/nadintamer/top-tracks-of-2017). The goals of this investigation is to see if there are particular "kinds" of songs that can be identified by clustering on their attributes.

# %% [markdown]
# ## TODO
#
# * Get numeric values only
# * Normalise
# * Try rough clustering analysis
# * Try PCA
# * Re-do rough clustering analysis
# * Do additional data scraping

# %%
import pandas as pd
import seaborn as sns
import sklearn

# %matplotlib inline

# %%
data = pd.read_csv('top-tracks-of-2017.csv')
data.head()
# Out:
#                       id                                name  \
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One
#
#             artists  danceability  energy   key  loudness  mode  speechiness  \
# 0        Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1        Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2        Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3  The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4         DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
data.shape
# Out:
# (100, 16)

# %%
sns.distplot(data['danceability'])

# %%
sns.distplot(data['energy'])

# %%
sns.distplot(data['key'])

# %%
sns.distplot(data['loudness'])

# %%
sns.distplot(data['mode'])

# %%
sns.distplot(data['speechiness'])

# %%
sns.distplot(data['acousticness'])

# %%
sns.distplot(data['instrumentalness'])

# %%
sns.distplot(data['liveness'])

# %%
sns.distplot(data['valence'])

# %%
sns.distplot(data['tempo'])

# %%
sns.distplot(data['duration_ms'])

# %%
sns.distplot(data['time_signature'])

# %%
data['time_signature'].value_counts()
# Out:
# 4.0    99
# 3.0     1
# Name: time_signature, dtype: int64
